# %% [markdown]
# ### N-gram language models or how to write scientific papers (4 pts)
#
# We shall train our language model on a corpora of [ArXiv](http://arxiv.org/) articles and see if we can generate a new one!
#
# ![img](https://media.npr.org/assets/img/2013/12/10/istock-18586699-monkey-computer_brick-16e5064d3378a14e0e4c2da08857efe03c04695e-s800-c85.jpg)
#
# _data by neelshah18 from [here](https://www.kaggle.com/neelshah18/arxivdataset/)_
#
# _Disclaimer: this has nothing to do with actual science. But it's fun, so who cares?!_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Alternative manual download link: https://yadi.sk/d/_nGyU2IajjR9-w
# !wget "https://www.dropbox.com/s/99az9n1b57qkd9j/arxivData.json.tar.gz?dl=1" -O arxivData.json.tar.gz
# !tar -xvzf arxivData.json.tar.gz
data = pd.read_json("./arxivData.json")
data.sample(n=5)
# Out:
# --2025-01-06 06:45:08--  https://www.dropbox.com/s/99az9n1b57qkd9j/arxivData.json.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/0mulrothty5o8i8ud9gz2/arxivData.json.tar.gz?rlkey=n759u5qx2xpxxglmrl390vwvk&dl=1 [following]
# --2025-01-06 06:45:09--  https://www.dropbox.com/scl/fi/0mulrothty5o8i8ud9gz2/arxivData.json.tar.gz?rlkey=n759u5qx2xpxxglmrl390vwvk&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com/cd/0/inline/Chr29XyumbZHhktWf9endfcEBltHHo4zml7jh7yJE7AchYaT5SO5Pl2DswqXRJHCqlxHptzStpwwBs1XPxwoSzFe7TIlGtF3ZiuCPYhweJ8GuwMOJZsmDcwGxDWvEFU4R9c/file?dl=1# [following]
# --2025-01-06 06:45:09--  https://ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com/cd/0/inline/Chr29XyumbZHhktWf9endfcEBltHHo4zml7jh7yJE7AchYaT5SO5Pl2DswqXRJHCqlxHptzStpwwBs1XPxwoSzFe7TIlGtF3ZiuCPYhweJ8GuwMOJZsmDcwGxDWvEFU4R9c/file?dl=1
# Resolving ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com (ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com (ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Chr5-q_qz6V2EQm5CTmoRGQQ2AweAxcY81qi-hHaZwpS7IqSXO25dfrgDQS-HCBlSFwnzE9YJycn8-H4raa_qG8QQ8i1Ov61FghiSA4lyLbKFDXW8z7Pgfl_dIRKMD46XVjpa_c0dtLHMf5gvQLs_oFnseJOIyZNHzT32zhtKbGkzPSN8KRTkvxMl_SELhLTw1SeAVPs0zCg7mYkHv5ieAChzQojR3ni4CGK72ZeW2_7VKYrsAXKLC602DGbnbiTuoUFsptMIq1SoAyJRDakRwh9LnpAsPr9Xs2lwhEgpIKVF8a0R1fSzhFWlSVYzlQcj2d5GlBHkwBVF13H-yhLiWItK4vHt-dQpxn4gekJo8DXGg/file?dl=1 [following]
# --2025-01-06 06:45:10--  https://ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com/cd/0/inline2/Chr5-q_qz6V2EQm5CTmoRGQQ2AweAxcY81qi-hHaZwpS7IqSXO25dfrgDQS-HCBlSFwnzE9YJycn8-H4raa_qG8QQ8i1Ov61FghiSA4lyLbKFDXW8z7Pgfl_dIRKMD46XVjpa_c0dtLHMf5gvQLs_oFnseJOIyZNHzT32zhtKbGkzPSN8KRTkvxMl_SELhLTw1SeAVPs0zCg7mYkHv5ieAChzQojR3ni4CGK72ZeW2_7VKYrsAXKLC602DGbnbiTuoUFsptMIq1SoAyJRDakRwh9LnpAsPr9Xs2lwhEgpIKVF8a0R1fSzhFWlSVYzlQcj2d5GlBHkwBVF13H-yhLiWItK4vHt-dQpxn4gekJo8DXGg/file?dl=1
# Reusing existing connection to ucce4b2ee468a3c0eae9af08707a.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18933283 (18M) [application/binary]
# Saving to: ‘arxivData.json.tar.gz’
#
# arxivData.json.tar. 100%[===================>]  18.06M  34.2MB/s    in 0.5s
#
# 2025-01-06 06:45:11 (34.2 MB/s) - ‘arxivData.json.tar.gz’ saved [18933283/18933283]
#
# arxivData.json
#                                                   author  day            id  \
# 31906  [{'name': 'Riad Akrour'}, {'name': 'Marc Schoe...    5   1208.0984v1
# 31436  [{'name': 'Huangying Zhan'}, {'name': 'Ravi Ga...   11  1803.03893v2
# 24757  [{'name': 'Mateusz Malinowski'}, {'name': 'Mar...   19   1411.5190v2
# 38271  [{'name': 'Luís Marujo'}, {'name': 'José Portê...    6  1508.01420v1
# 28936  [{'name': 'Saksham Gupta'}, {'name': 'Sukhad A...    2  1708.00884v1
#
#                                                     link  month  \
# 31906  [{'rel': 'alternate', 'href': 'http://arxiv.or...      8
# 31436  [{'rel': 'alternate', 'href': 'http://arxiv.or...      3
# 24757  [{'rel': 'alternate', 'href': 'http://arxiv.or...     11
# 38271  [{'rel': 'alternate', 'href': 'http://arxiv.or...      8
# 28936  [{'rel': 'alternate', 'href': 'http://arxiv.or...      8
#
#                                                  summary  \
# 31906  This paper focuses on reinforcement learning (...
# 31436  Despite learning based methods showing promisi...
# 24757  Over the last two decades we have witnessed st...
# 38271  State-of-the-art extractive multi-document sum...
# 28936  In the previous decade, there has been a consi...
#
#                                                      tag  \
# 31906  [{'term': 'cs.LG', 'scheme': 'http://arxiv.org...
# 31436  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
# 24757  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
# 38271  [{'term': 'cs.IR', 'scheme': 'http://arxiv.org...
# 28936  [{'term': 'cs.CV', 'scheme': 'http://arxiv.org...
#
#                                                    title  year
# 31906  APRIL: Active Preference-learning based Reinfo...  2012
# 31436  Unsupervised Learning of Monocular Depth Estim...  2018
# 24757  A Pooling Approach to Modelling Spatial Relati...  2014
# 38271    Privacy-Preserving Multi-Document Summarization  2015
# 28936     Fingerprint Extraction Using Smartphone Camera  2017

# %%
# assemble lines: concatenate title and description
lines = data.apply(lambda row: row['title'] + ' ; ' + row['summary'].replace("\n", ' '), axis=1).tolist()

sorted(lines, key=len)[:3]
# Out:
# ['Differential Contrastive Divergence ; This paper has been retracted.',
#  'What Does Artificial Life Tell Us About Death? ; Short philosophical essay',
#  'P=NP ; We claim to resolve the P=?NP problem via a formal argument for P=NP.']

# %% [markdown]
# ### Tokenization
#
# You know the dril. The data is messy. Go clean the data. Use WordPunctTokenizer or something.

# %%
# Task: convert lines (in-place) into strings of space-separated tokens. Import & use WordPunctTokenizer

from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
lines = [' '.join(tokenizer.tokenize(line)).lower() for line in lines]

# %%
assert sorted(lines, key=len)[0] == \
    'differential contrastive divergence ; this paper has been retracted .'
assert sorted(lines, key=len)[2] == \
    'p = np ; we claim to resolve the p =? np problem via a formal argument for p = np .'

# %% [markdown]
# ### N-Gram Language Model (1point)
#
# A language model is a probabilistic model that estimates text probability: the joint probability of all tokens $w_t$ in text $X$: $P(X) = P(w_1, \dots, w_T)$.
#
# It can do so by following the chain rule:
# $$P(w_1, \dots, w_T) = P(w_1)P(w_2 \mid w_1)\dots P(w_T \mid w_1, \dots, w_{T-1}).$$
#
# The problem with such approach is that the final term $P(w_T \mid w_1, \dots, w_{T-1})$ depends on $n-1$ previous words. This probability is impractical to estimate for long texts, e.g. $T = 1000$.
#
# One popular approximation is to assume that next word only depends on a finite amount of previous words:
#
# $$P(w_t \mid w_1, \dots, w_{t - 1}) = P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1})$$
#
# Such model is called __n-gram language model__ where n is a parameter. For example, in 3-gram language model, each word only depends on 2 previous words.
#
# $$
#     P(w_1, \dots, w_n) = \prod_t P(w_t \mid w_{t - n + 1}, \dots, w_{t - 1}).
# $$
#
# You can also sometimes see such approximation under the name of _n-th order markov assumption_.

# %% [markdown]
# The first stage to building such a model is counting all word occurences given N-1 previous words

# %%
from tqdm import tqdm
from collections import defaultdict, Counter

# special tokens:
# - `UNK` represents absent tokens,
# - `EOS` is a special token after the end of sequence

UNK, EOS = "_UNK_", "_EOS_"

def count_ngrams(lines, n):
    """
    Count how many times each word occured after (n - 1) previous words
    :param lines: an iterable of strings with space-separated tokens
    :returns: a dictionary { tuple(prefix_tokens): {next_token_1: count_1, next_token_2: count_2}}

    When building counts, please consider the following two edge cases:
    - if prefix is shorter than (n - 1) tokens, it should be padded with UNK. For n=3,
      empty prefix: "" -> (UNK, UNK)
      short prefix: "the" -> (UNK, the)
      long prefix: "the new approach" -> (new, approach)
    - you should add a special token, EOS, at the end of each sequence
      "... with deep neural networks ." -> (..., with, deep, neural, networks, ., EOS)
      count the probability of this token just like all others.
    """
    counts = defaultdict(Counter)
    # counts[(word1, word2)][word3] = how many times word3 occured after (word1, word2)
    for line in lines:
        tokens = [UNK] * (n - 1) + line.split() + [EOS]
        for i in range(n - 1, len(tokens)):
          counts[tuple(tokens[i-n+1:i])][tokens[i]] += 1

    return counts

# %%
dummy_counts
# Out:
# defaultdict(collections.Counter,
#             {('_UNK_', '_UNK_'): 'learning',
#              ('_UNK_', 'differential'): 'contrastive',
#              ('differential', 'contrastive'): 'divergence',
#              ('contrastive', 'divergence'): ';',
#              ('divergence', ';'): 'this',
#              (';', 'this'): 'manuscripts',
#              ('this', 'paper'): 'we',
#              ('paper', 'has'): 'been',
#              ('has', 'been'): 'withdrawn',
#              ('been', 'retracted'): '.',
#              ('retracted', '.'): '_EOS_',
#              ('_UNK_', 'what'): 'does',
#              ('what', 'does'): 'artificial',
#              ('does', 'artificial'): 'life',
#              ('artificial', 'life'): 'journal',
#              ('life', 'tell'): 'us',
#              ('tell', 'us'): 'about',
#              ('us', 'about'): 'death',
#              ('about', 'death'): '?',
#              ('death', '?'): ';',
#              ('?', ';'): 'computer',
#              (';', 'short'): 'philosophical',
#              ('short', 'philosophical'): 'essay',
#              ('philosophical', 'essay'): '_EOS_',
#              ('_UNK_', 'p'): '=',
#              ('p', '='): 'np',
#              ('=', 'np'): '.',
#              ('np', ';'): 'we',
#              (';', 'we'): 'propose',
#              ('we', 'claim'): 'to',
#              ('claim', 'to'): 'resolve',
#              ('to', 'resolve'): 'the',
#              ('resolve', 'the'): 'p',
#              ('the', 'p'): '=?',
#              ('p', '=?'): 'np',
#              ('=?', 'np'): 'problem',
#              ('np', 'problem'): 'via',
#              ('problem', 'via'): 'a',
#              ('via', 'a'): 'formal',
#              ('a', 'formal'): 'argument',
#              ('formal', 'argument'): 'for',
#              ('argument', 'for'): 'p',
#              ('for', 'p'): '=',
#              ('np', '.'): '_EOS_',
#              ('_UNK_', 'computational'): 'geometry',
#              ('computational', 'geometry'): 'column',
#              ('geometry', 'column'): '38',
#              ('column', '38'): ';',
#              ('38', ';'): 'recent',
#              (';', 'recent'): 'results',
#              ('recent', 'results'): 'on',
#              ('results', 'on'): 'curve',
#              ('on', 'curve'): 'reconstruction',
#              ('curve', 'reconstruction'): 'are',
#              ('reconstruction', 'are'): 'described',
#              ('are', 'described'): ',',
#              ('described', '.'): '_EOS_',
#              ('_UNK_', 'weak'): 'evolvability',
#              ('weak', 'evolvability'): 'equals',
#              ('evolvability', 'equals'): 'strong',
#              ('equals', 'strong'): 'evolvability',
#              ('strong', 'evolvability'): ';',
#              ('evolvability', ';'): 'an',
#              (';', 'an'): 'updated',
#              ('an', 'updated'): 'version',
#              ('updated', 'version'): 'will',
#              ('version', 'will'): 'be',
#              ('will', 'be'): 'posted',
#              ('be', 'uploaded'): 'later',
#              ('uploaded', 'later'): '.',
#              ('later', '.'): '_EOS_',
#              ('_UNK_', 'creating'): 'a',
#              ('creating', 'a'): 'new',
#              ('a', 'new'): 'mutation',
#              ('new', 'ontology'): ':',
#              ('ontology', ':'): 'a',
#              (':', 'a'): 'tool',
#              ('a', 'modular'): 'approach',
#              ('modular', 'approach'): '_EOS_',
#              ('approach', ';'): 'creating',
#              (';', 'creating'): 'a',
#              ('_UNK_', 'defeasible'): 'reasoning',
#              ('defeasible', 'reasoning'): 'in',
#              ('reasoning', 'in'): 'oscar',
#              ('in', 'oscar'): ';',
#              ('oscar', ';'): 'this',
#              ('this', 'is'): 'the',
#              ('is', 'a'): 'learning',
#              ('a', 'system'): 'description',
#              ('system', 'description'): 'for',
#              ('description', 'for'): 'the',
#              ('for', 'the'): 'completeness',
#              ('the', 'oscar'): 'defeasible',
#              ('oscar', 'defeasible'): 'reasoner',
#              ('defeasible', 'reasoner'): '.',
#              ('reasoner', '.'): '_EOS_',
#              ('_UNK_', 'essence'): "'",
#              ('essence', "'"): 'language',
#              ("'", 'description'): ';',
#              ('description', ';'): 'a',
#              (';', 'a'): 'introduction',
#              ('a', 'description'): 'and',
#              ('description', 'of'): 'the',
#              ('of', 'the'): 'liver',
#              ('the', 'essence'): "'",
#              ("'", 'language'): 'as',
#              ('language', 'as'): 'used',
#              ('as', 'used'): 'by',
#              ('used', 'by'): 'the',
#              ('by', 'the'): 'author',
#              ('the', 'tool'): 'savile',
#              ('tool', 'savile'): 'row',
#              ('savile', 'row'): '.',
#              ('row', '.'): '_EOS_',
#              ('_UNK_', 'deep'): 'neural',
#              ('deep', 'neural'): 'networks',
#              ('neural', 'networks'): '.',
#              ('networks', '-'): 'a',
#              ('-', 'a'): 'brief',
#              ('a', 'brief'): 'history',
#              ('brief', 'history'): ';',
#              ('history', ';'): 'introduction',
#              (';', 'introduction'): 'to',
#              ('introduction', 'to'): 'the',
#              ('to', 'deep'): 'neural',
#              ('networks', 'and'): 'their',
#              ('and', 'their'): 'meaning',
#              ('their', 'history'): '.',
#              ('history', '.'): '_EOS_',
#              ('_UNK_', 'statistical'): 'physics',
#              ('statistical', 'physics'): 'for',
#              ('physics', 'for'): 'natural',
#              ('for', 'natural'): 'language',
#              ('natural', 'language'): 'to',
#              ('language', 'processing'): '.',
#              ('processing', ';'): 'this',
#              ('been', 'withdrawn'): 'by',
#              ('withdrawn', 'by'): 'arxiv',
#              ('the', 'author'): 'due',
#              ('author', '.'): '_EOS_',
#              ('_UNK_', 'complex'): 'networks',
#              ('complex', 'networks'): '"',
#              ('networks', ';'): 'this',
#              ('to', 'the'): 'syntax',
#              ('the', 'special'): 'issue',
#              ('special', 'issue'): '_EOS_',
#              ('issue', 'on'): 'complex',
#              ('on', 'complex'): 'networks',
#              ('networks', ','): 'artificial',
#              (',', 'artificial'): 'life',
#              ('life', 'journal'): '.',
#              ('journal', '.'): '_EOS_',
#              ('_UNK_', 'serious'): 'flaws',
#              ('serious', 'flaws'): 'in',
#              ('flaws', 'in'): 'korf',
#              ('in', 'korf'): 'et',
#              ('korf', 'et'): 'al',
#              ('et', 'al'): ".'",
#              ('al', ".'"): 's',
#              (".'", 's'): 'analysis',
#              ('s', 'analysis'): 'on',
#              ('analysis', 'on'): 'time',
#              ('on', 'time'): 'complexity',
#              ('time', 'complexity'): 'of',
#              ('complexity', 'of'): 'a',
#              ('of', 'a'): 'fundamental',
#              ('a', '*'): ';',
#              ('*', ';'): 'this',
#              ('withdrawn', '.'): '_EOS_',
#              ('_UNK_', 'preprocessing'): ':',
#              ('preprocessing', ':'): 'a',
#              ('a', 'step'): 'in',
#              ('step', 'in'): 'automating',
#              ('in', 'automating'): 'early',
#              ('automating', 'early'): 'detection',
#              ('early', 'detection'): 'of',
#              ('detection', 'of'): 'cervical',
#              ('of', 'cervical'): 'cancer',
#              ('cervical', 'cancer'): ';',
#              ('cancer', ';'): 'this',
#              ('_UNK_', 'liquid'): 'state',
#              ('liquid', 'state'): 'machines',
#              ('state', 'machines'): 'in',
#              ('machines', 'in'): 'adbiatic',
#              ('in', 'adbiatic'): 'quantum',
#              ('adbiatic', 'quantum'): 'computers',
#              ('quantum', 'computers'): 'for',
#              ('computers', 'for'): 'general',
#              ('for', 'general'): 'computation',
#              ('general', 'computation'): ';',
#              ('computation', ';'): 'major',
#              (';', 'major'): 'mistakes',
#              ('major', 'mistakes'): 'do',
#              ('mistakes', 'do'): 'not',
#              ('do', 'not'): 'read',
#              ('not', 'read'): '_EOS_',
#              ('_UNK_', 'mining'): 'for',
#              ('mining', 'for'): 'trees',
#              ('for', 'trees'): 'in',
#              ('trees', 'in'): 'a',
#              ('in', 'a'): 'playful',
#              ('a', 'graph'): 'is',
#              ('graph', 'is'): 'shown',
#              ('is', 'np'): '-',
#              ('np', '-'): 'complete',
#              ('-', 'complete'): '.',
#              ('complete', ';'): 'mining',
#              (';', 'mining'): 'for',
#              ('is', 'shown'): 'that',
#              ('shown', 'to'): 'be',
#              ('to', 'be'): 'np',
#              ('be', 'np'): '-',
#              ('complete', '.'): '_EOS_',
#              ('_UNK_', 'towards'): 'a',
#              ('towards', 'a'): 'hierarchical',
#              ('a', 'hierarchical'): 'model',
#              ('hierarchical', 'model'): 'of',
#              ('model', 'of'): 'a',
#              ('of', 'consciousness'): ',',
#              ('consciousness', ','): 'intelligence',
#              (',', 'intelligence'): ',',
#              ('intelligence', ','): 'mind',
#              (',', 'mind'): 'and',
#              ('mind', 'and'): 'body',
#              ('and', 'body'): ';',
#              ('body', ';'): 'this',
#              ('this', 'article'): 'has',
#              ('article', 'is'): 'written',
#              ('is', 'taken'): 'out',
#              ('taken', 'out'): '.',
#              ('out', '.'): '_EOS_',
#              ('_UNK_', 'a'): 'primer',
#              ('a', 'notation'): 'for',
#              ('notation', 'for'): 'markov',
#              ('for', 'markov'): 'decision',
#              ('markov', 'decision'): 'processes',
#              ('decision', 'processes'): '.',
#              ('processes', ';'): 'this',
#              ('paper', 'specifies'): 'a',
#              ('specifies', 'a'): 'notation',
#              ('processes', '.'): '_EOS_',
#              ('_UNK_', 'icon'): 'challenge',
#              ('icon', 'challenge'): 'on',
#              ('challenge', 'on'): 'algorithm',
#              ('on', 'algorithm'): 'selection',
#              ('algorithm', 'selection'): '.',
#              ('selection', ';'): 'we',
#              ('we', 'present'): 'our',
#              ('present', 'the'): 'results',
#              ('the', 'results'): 'of',
#              ('results', 'of'): 'object',
#              ('the', 'icon'): 'challenge',
#              ('selection', '.'): '_EOS_',
#              ('_UNK_', 'recognition'): 'of',
#              ('recognition', 'of'): 'regular',
#              ('of', 'regular'): 'shapes',
#              ('regular', 'shapes'): 'in',
#              ('shapes', 'in'): 'satelite',
#              ('in', 'satelite'): 'images',
#              ('satelite', 'images'): ';',
#              ('images', ';'): 'the',
#              ('author', 'ali'): 'pourmohammad',
#              ('ali', 'pourmohammad'): '.',
#              ('pourmohammad', '.'): '_EOS_',
#              ('_UNK_', 'glottochronologic'): 'retrognostic',
#              ('glottochronologic', 'retrognostic'): 'of',
#              ('retrognostic', 'of'): 'language',
#              ('of', 'language'): 'system',
#              ('language', 'system'): 'is',
#              ('system', ';'): 'we',
#              ('a', 'glottochronologic'): 'retrognostic',
#              ('system', 'is'): 'proposed',
#              ('is', 'proposed'): '.',
#              ('_UNK_', 'the'): 'logic',
#              ('the', 'model'): 'of',
#              ('of', 'quantum'): 'evolution',
#              ('quantum', 'evolution'): ';',
#              ('evolution', ';'): 'this',
#              ('author', 'due'): 'to',
#              ('due', 'to'): 'a',
#              ('to', 'extremely'): 'unscientific',
#              ('extremely', 'unscientific'): 'errors',
#              ('unscientific', 'errors'): '.',
#              ('errors', '.'): '_EOS_',
#              ('_UNK_', 'utility'): '-',
#              ('utility', '-'): 'probability',
#              ('-', 'probability'): 'duality',
#              ('probability', 'duality'): ';',
#              ('duality', ';'): 'this',
#              ('paper', 'presents'): 'an',
#              ('presents', 'duality'): 'between',
#              ('duality', 'between'): 'probability',
#              ('between', 'probability'): 'distributions',
#              ('probability', 'distributions'): 'and',
#              ('distributions', 'and'): 'utility',
#              ('and', 'utility'): 'functions',
#              ('utility', 'functions'): '.',
#              ('functions', '.'): '_EOS_',
#              ('_UNK_', 'temporized'): 'equilibria',
#              ('temporized', 'equilibria'): ';',
#              ('equilibria', ';'): 'this',
#              ('to', 'a'): 'crucial',
#              ('a', 'crucial'): 'sign',
#              ('crucial', 'error'): 'in',
#              ('error', 'in'): 'equation',
#              ('in', 'the'): 'area',
#              ('the', 'submission'): 'action',
#              ('submission', 'action'): '.',
#              ('action', '.'): '_EOS_',
#              ('_UNK_', 'backpropagation'): 'in',
#              ('backpropagation', 'in'): 'matrix',
#              ('in', 'matrix'): 'notation',
#              ('matrix', 'notation'): '.',
#              ('notation', ';'): 'in',
#              (';', 'in'): 'this',
#              ('in', 'this'): 'paper',
#              ('this', 'note'): 'we',
#              ('note', 'we'): 'study',
#              ('we', 'calculate'): 'the',
#              ('calculate', 'the'): 'distance',
#              ('the', 'gradient'): 'of',
#              ('gradient', 'of'): 'the',
#              ('the', 'network'): 'function',
#              ('network', 'function'): 'in',
#              ('function', 'in'): 'matrix',
#              ('notation', '.'): '_EOS_',
#              ('_UNK_', 'random'): 'dfas',
#              ('random', 'dfas'): 'are',
#              ('dfas', 'are'): 'efficiently',
#              ('are', 'efficiently'): 'pac',
#              ('efficiently', 'pac'): 'learnable',
#              ('pac', 'learnable'): ';',
#              ('learnable', ';'): 'this',
#              ('withdrawn', 'due'): 'to',
#              ('to', 'an'): 'error',
#              ('an', 'error'): 'found',
#              ('error', 'found'): 'by',
#              ('found', 'by'): 'dana',
#              ('by', 'dana'): 'angluin',
#              ('dana', 'angluin'): 'and',
#              ('angluin', 'and'): 'lev',
#              ('and', 'lev'): 'reyzin',
#              ('lev', 'reyzin'): '.',
#              ('reyzin', '.'): '_EOS_',
#              ('_UNK_', 'network'): 'motifs',
#              ('network', 'motifs'): 'in',
#              ('motifs', 'in'): 'music',
#              ('in', 'music'): 'sequences',
#              ('music', 'sequences'): ';',
#              ('sequences', ';'): 'this',
#              ('author', 'because'): 'it',
#              ('because', 'it'): 'is',
#              ('it', 'needs'): 'a',
#              ('needs', 'a'): 'deep',
#              ('a', 'deep'): 'methodological',
#              ('deep', 'methodological'): 'revision',
#              ('methodological', 'revision'): '.',
#              ('revision', '.'): '_EOS_',
#              ('_UNK_', 'glottochronology'): 'and',
#              ('glottochronology', 'and'): 'problems',
#              ('and', 'problems'): 'of',
#              ('problems', 'of'): 'protolanguage',
#              ('of', 'protolanguage'): 'reconstruction',
#              ('protolanguage', 'reconstruction'): ';',
#              ('reconstruction', ';'): 'in',
#              ('a', 'method'): 'for',
#              ('method', 'of'): 'using',
#              ('of', 'languages'): 'genealogical',
#              ('languages', 'genealogical'): 'trees',
#              ('genealogical', 'trees'): 'construction',
#              ('trees', 'construction'): 'is',
#              ('construction', 'is'): 'proposed',
#              ('proposed', '.'): '_EOS_',
#              ('_UNK_', 'using'): 'sets',
#              ('using', 'slp'): 'neural',
#              ('slp', 'neural'): 'network',
#              ('neural', 'network'): 'building',
#              ('network', 'to'): 'persian',
#              ('to', 'persian'): 'handwritten',
#              ('persian', 'handwritten'): 'digits',
#              ('handwritten', 'digits'): 'recognition',
#              ('digits', 'recognition'): ';',
#              ('recognition', ';'): 'this',
#              ('_UNK_', 'time'): 'hopping',
#              ('time', 'hopping'): 'technique',
#              ('hopping', 'technique'): 'for',
#              ('technique', 'for'): 'faster',
#              ('for', 'faster'): 'reinforcement',
#              ('faster', 'reinforcement'): 'learning',
#              ('reinforcement', 'learning'): 'in',
#              ('learning', 'in'): 'simulations',
#              ('in', 'simulations'): ';',
#              ('simulations', ';'): 'this',
#              ('this', 'preprint'): 'has',
#              ('preprint', 'has'): 'been',
#              ('author', 'for'): 'revision',
#              ('for', 'revision'): '_EOS_',
#              ('_UNK_', 'convolutional'): 'matching',
#              ('convolutional', 'matching'): 'pursuit',
#              ('matching', 'pursuit'): 'and',
#              ('pursuit', 'and'): 'k',
#              ('and', 'dictionary'): 'training',
#              ('dictionary', 'training'): ';',
#              ('training', ';'): 'matching',
#              (';', 'matching'): 'pursuit',
#              ('and', 'k'): '-',
#              ('k', '-'): 'svd',
#              ('-', 'svd'): 'is',
#              ('svd', 'is'): 'demonstrated',
#              ('is', 'demonstrated'): 'in',
#              ('demonstrated', 'in'): 'the',
#              ('the', 'translation'): 'invariant',
#              ('translation', 'invariant'): 'setting',
#              ('invariant', 'setting'): '_EOS_',
#              ('_UNK_', 'fitness'): 'landscape',
#              ('fitness', 'landscape'): 'analysis',
#              ('landscape', 'analysis'): 'for',
#              ('analysis', 'for'): 'paracontracting',
#              ('for', 'dynamic'): 'resource',
#              ('dynamic', 'resource'): 'allocation',
#              ('resource', 'allocation'): 'of',
#              ('allocation', 'in'): 'multiuser',
#              ('in', 'multiuser'): 'ofdm',
#              ('multiuser', 'ofdm'): 'based',
#              ('ofdm', 'based'): 'cognitive',
#              ('based', 'cognitive'): 'radio',
#              ('cognitive', 'radio'): 'systems',
#              ('radio', 'systems'): 'under',
#              ('systems', ';'): 'this',
#              ('a', 'note'): 'on',
#              ('note', 'on'): 'adjusting',
#              ('on', 'darwiche'): 'and',
#              ('darwiche', 'and'): 'pearl',
#              ('and', 'pearl'): "'",
#              ('pearl', ';'): 'it',
#              (';', 'it'): 'is',
#              ('it', 'is'): 'intentionally',
#              ('shown', 'that'): 'darwiche',
#              ('that', 'darwiche'): 'and',
#              ('pearl', "'"): 's',
#              ("'", 's'): 'assumption',
#              ('s', 'postulates'): 'imply',
#              ('postulates', 'imply'): 'an',
#              ('imply', 'an'): 'interesting',
#              ('an', 'interesting'): 'property',
#              ('interesting', 'property'): ',',
#              ('property', ','): 'not',
#              (',', 'not'): 'noticed',
#              ('not', 'noticed'): 'by',
#              ('noticed', 'by'): 'the',
#              ('the', 'authors'): 'due',
#              ('authors', '.'): '_EOS_',
#              ('_UNK_', 'flip'): '-',
#              ('flip', '-'): 'flop',
#              ('-', 'flop'): 'sublinear',
#              ('flop', 'sublinear'): 'models',
#              ('sublinear', 'models'): 'on',
#              ('models', 'for'): 'graphs',
#              ('for', 'graphs'): ':',
#              ('graphs', ':'): 'proof',
#              (':', 'proof'): 'of',
#              ('proof', 'of'): 'theorem',
#              ('of', 'theorem'): '1',
#              ('theorem', '1'): ';',
#              ('1', ';'): 'we',
#              ('we', 'prove'): 'that',
#              ('prove', 'that'): 'there',
#              ('that', 'there'): 'is',
#              ('there', 'is'): 'no',
#              ('is', 'no'): 'more',
#              ('no', 'class'): '-',
#              ('class', '-'): 'dual',
#              ('-', 'dual'): 'message',
#              ('dual', 'for'): 'almost',
#              ('for', 'almost'): 'all',
#              ('almost', 'all'): 'sublinear',
#              ('all', 'sublinear'): 'models',
#              ('models', 'on'): 'graphs',
#              ('on', 'graphs'): '.',
#              ('graphs', '.'): '_EOS_',
#              ('_UNK_', 'autonomous'): 'perceptron',
#              ('autonomous', 'perceptron'): 'neural',
#              ('perceptron', 'neural'): 'network',
#              ('network', 'inspired'): 'from',
#              ('inspired', 'from'): 'quantum',
#              ('from', 'quantum'): 'computing',
#              ('quantum', 'computing'): ';',
#              ('computing', ';'): 'this',
#              ('this', 'abstract'): 'will',
#              ('abstract', 'will'): 'be',
#              ('be', 'modified'): 'after',
#              ('modified', 'after'): 'correcting',
#              ('after', 'correcting'): 'the',
#              ('correcting', 'the'): 'minor',
#              ('the', 'minor'): 'error',
#              ('minor', 'error'): 'in',
#              ('in', 'eq'): '.(',
#              ('eq', '.('): '2',
#              ('.(', '2'): ')',
#              ('2', ')'): '_EOS_',
#              ('using', 'sets'): 'of',
#              ('sets', 'of'): 'probability',
#              ('of', 'probability'): 'measures',
#              ('probability', 'measures'): 'as',
#              ('measures', 'to'): 'represent',
#              ('to', 'represent'): 'uncertainty',
#              ('represent', 'uncertainty'): ';',
#              ('uncertainty', ';'): 'we',
#              (';', 'i'): 'explore',
#              ('i', 'explore'): 'the',
#              ('explore', 'the'): 'use',
#              ('the', 'use'): 'of',
#              ('use', 'of'): 'the',
#              ('of', 'sets'): 'of',
#              ('measures', 'as'): 'a',
#              ('as', 'a'): 'game',
#              ('a', 'representation'): 'of',
#              ('representation', 'of'): 'sat',
#              ('of', 'uncertainty'): '.',
#              ('uncertainty', '.'): '_EOS_',
#              ('a', 'comment'): 'on',
#              ('comment', 'on'): '"',
#              ('on', 'argumentation'): ';',
#              ('argumentation', ';'): 'we',
#              ('we', 'use'): 'marker',
#              ('use', 'the'): 'theory',
#              ('the', 'theory'): 'of',
#              ('theory', 'of'): 'experiment',
#              ('of', 'defaults'): 'and',
#              ('defaults', 'and'): 'their',
#              ('their', 'meaning'): 'of',
#              ('meaning', 'of'): '[',
#              ('of', '['): 'gs16',
#              ('[', 'gs16'): ']',
#              ('gs16', ']'): 'to',
#              (']', 'to'): 'develop',
#              ('to', 'develop'): 'a',
#              ('develop', '('): 'the',
#              ('(', 'the'): 'outline',
#              ('the', 'outline'): 'of',
#              ('outline', 'of'): 'a',
#              ('a', ')'): 'new',
#              (')', 'new'): 'theory',
#              ('new', 'theory'): 'of',
#              ('of', 'argumentation'): '.',
#              ('argumentation', '.'): '_EOS_',
#              ('_UNK_', 'activitynet'): 'challenge',
#              ('activitynet', 'challenge'): '2017',
#              ('challenge', '2017'): 'summary',
#              ('2017', 'summary'): ':',
#              ('summary', ';'): 'the',
#              (';', 'the'): 'aim',
#              ('the', 'activitynet'): 'large',
#              ('activitynet', 'large'): 'scale',
#              ('large', 'scale'): 'structured',
#              ('scale', 'activity'): 'recognition',
#              ('activity', 'recognition'): 'challenge',
#              ('recognition', 'challenge'): '2017',
#              ('summary', ':'): 'results',
#              (':', 'results'): 'and',
#              ('results', 'and'): 'challenge',
#              ('and', 'challenge'): 'participants',
#              ('challenge', 'participants'): 'papers',
#              ('participants', 'papers'): '.',
#              ('papers', '.'): '_EOS_',
#              ('the', 'yahoo'): 'webscope',
#              ('yahoo', 'query'): 'treebank',
#              ('query', 'treebank'): ',',
#              ('treebank', ','): 'version',
#              (',', 'v'): '.',
#              ('v', '.'): '1',
#              ('.', '1'): 'will',
#              ('1', '.'): '3',
#              ('.', '0'): ',',
#              ('0', ';'): 'a',
#              ('description', 'and'): 'annotation',
#              ('and', 'annotation'): 'guidelines',
#              ('annotation', 'guidelines'): 'for',
#              ('guidelines', 'for'): 'the',
#              ('yahoo', 'webscope'): 'release',
#              ('webscope', 'release'): 'of',
#              ('release', 'of'): 'query',
#              ('of', 'query'): 'treebank',
#              (',', 'version'): '1',
#              ('version', '1'): '.',
#              ('0', ','): 'may',
#              (',', 'may'): '17',
#              ('may', '2016'): '.',
#              ('2016', '.'): '_EOS_',
#              ('_UNK_', 'decision'): 'under',
#              ('decision', 'under'): 'uncertainty',
#              ('under', 'uncertainty'): ';',
#              ('we', 'derive'): 'axiomatically',
#              ('derive', 'axiomatically'): 'the',
#              ('axiomatically', 'the'): 'probability',
#              ('the', 'probability'): 'function',
#              ('probability', 'function'): 'that',
#              ('function', 'that'): 'should',
#              ('that', 'should'): 'be',
#              ('should', 'be'): 'used',
#              ('be', 'used'): 'to',
#              ('used', 'to'): 'make',
#              ('to', 'make'): 'decisions',
#              ('make', 'decisions'): 'given',
#              ('decisions', 'given'): 'any',
#              ('given', 'any'): 'form',
#              ('any', 'form'): 'of',
#              ('form', 'of'): 'underlying',
#              ('of', 'underlying'): 'uncertainty',
#              ('underlying', 'uncertainty'): '.',
#              ('_UNK_', 'text'): 'analysis',
#              ('text', 'analysis'): 'tools',
#              ('analysis', 'tools'): 'in',
#              ('tools', 'in'): 'spoken',
#              ('in', 'spoken'): 'language',
#              ('spoken', 'language'): 'processing',
#              ('this', 'submission'): 'has',
#              ('submission', 'contains'): 'the',
#              ('contains', 'the'): 'proofs',
#              ('the', 'postscript'): 'of',
#              ('postscript', 'of'): 'the',
#              ('the', 'final'): 'version',
#              ('final', 'version'): 'of',
#              ('version', 'of'): 'the',
#              ('the', 'slides'): 'used',
#              ('slides', 'used'): 'in',
#              ('used', 'in'): 'our',
#              ('in', 'our'): 'acl',
#              ('our', 'acl'): '-',
#              ('acl', '-'): '94',
#              ('-', '94'): 'tutorial',
#              ('94', 'tutorial'): '.',
#              ('tutorial', '.'): '_EOS_',
#              ('_UNK_', 'discrimination'): 'between',
#              ('discrimination', 'between'): 'arabic',
#              ('between', 'arabic'): 'and',
#              ('arabic', 'and'): 'latin',
#              ('and', 'latin'): 'from',
#              ('latin', 'from'): 'bilingual',
#              ('from', 'bilingual'): 'documents',
#              ('bilingual', 'documents'): ';',
#              ('documents', ';'): '2011',
#              (';', '2011'): 'international',
#              ('2011', 'international'): 'conference',
#              ('international', 'conference'): 'on',
#              ('conference', 'on'): 'logic',
#              ('on', 'communications'): ',',
#              ('communications', ','): 'computing',
#              (',', 'computing'): 'and',
#              ('computing', 'and'): 'control',
#              ('and', 'control'): 'applications',
#              ('control', 'applications'): '(',
#              ('applications', '('): 'ccca',
#              ('(', 'ccca'): ')',
#              ('ccca', ')'): '_EOS_',
#              ('a', 'machine'): 'learning',
#              ('machine', '-'): 'learning',
#              ('-', 'learning'): 'framework',
#              ('learning', 'framework'): 'for',
#              ('framework', 'for'): 'mapping',
#              ('for', 'design'): 'for',
#              ('design', 'for'): 'manufacturability',
#              ('for', 'manufacturability'): ';',
#              ('manufacturability', ';'): 'this',
#              ('a', 'duplicate'): 'submission',
#              ('duplicate', 'submission'): '(',
#              ('submission', '('): 'original',
#              ('(', 'original'): 'is',
#              ('original', 'is'): 'arxiv',
#              ('is', 'arxiv'): ':',
#              ('arxiv', ':'): '0711',
#              (':', '1612'): '.',
#              ('1612', '.'): '02141',
#              ('.', '02141'): ').',
#              ('02141', ').'): 'hence',
#              (').', 'hence'): 'want',
#              ('hence', 'want'): 'to',
#              ('want', 'to'): 'withdraw',
#              ('to', 'withdraw'): 'it',
#              ('withdraw', 'it'): '_EOS_',
#              ('a', 'theory'): 'of',
#              ('of', 'experiment'): ';',
#              ('experiment', ';'): 'this',
#              ('article', 'aims'): 'at',
#              ('aims', 'at'): 'clarifying',
#              ('at', 'clarifying'): 'the',
#              ('clarifying', 'the'): 'language',
#              ('the', 'language'): 'and',
#              ('language', 'and'): 'practice',
#              ('and', 'practice'): 'of',
#              ('practice', 'of'): 'scientific',
#              ('of', 'scientific'): 'experiment',
#              ('scientific', 'experiment'): ',',
#              ('experiment', ','): 'mainly',
#              (',', 'mainly'): 'by',
#              ('mainly', 'by'): 'hooking',
#              ('by', 'hooking'): 'observability',
#              ('hooking', 'observability'): 'on',
#              ('observability', 'on'): 'calculability',
#              ('on', 'calculability'): '.',
#              ('calculability', '.'): '_EOS_',
#              ('_UNK_', 'are'): 'minds',
#              ('are', 'minds'): 'computable',
#              ('minds', 'computable'): '?',
#              ('computable', '?'): ';',
#              ('this', 'essay'): 'explores',
#              ('essay', 'explores'): 'the',
#              ('explores', 'the'): 'limits',
#              ('the', 'limits'): 'of',
#              ('limits', 'of'): 'turing',
#              ('of', 'turing'): 'machines',
#              ('turing', 'machines'): 'concerning',
#              ('machines', 'concerning'): 'the',
#              ('concerning', 'the'): 'modeling',
#              ('the', 'modeling'): 'of',
#              ('modeling', 'of'): 'minds',
#              ('of', 'minds'): 'and',
#              ('minds', 'and'): 'suggests',
#              ('and', 'suggests'): 'alternatives',
#              ('suggests', 'alternatives'): 'to',
#              ('alternatives', 'to'): 'go',
#              ('to', 'go'): 'beyond',
#              ('go', 'beyond'): 'those',
#              ('beyond', 'those'): 'limits',
#              ('those', 'limits'): '.',
#              ('limits', '.'): '_EOS_',
#              ('_UNK_', 'extraction'): 'de',
#              ('extraction', 'de'): 'concepts',
#              ('de', 'concepts'): 'sous',
#              ('concepts', 'sous'): 'contraintes',
#              ('sous', 'contraintes'): 'dans',
#              ('contraintes', 'dans'): 'des',
#              ('dans', 'des'): 'données',
#              ('des', 'données'): 'd',
#              ('données', 'd'): "'",
#              ('d', "'"): 'expression',
#              ("'", 'expression'): 'de',
#              ('expression', 'de'): 'gènes',
#              ('de', 'gènes'): ';',
#              ('gènes', ';'): 'in',
#              ('paper', ','): 'we',
#              (',', 'we'): 'briefly',
#              ('we', 'propose'): 'to',
#              ('propose', 'a'): 'new',
#              ('a', 'technique'): 'to',
#              ('technique', 'to'): 'extract',
#              ('to', 'extract'): 'constrained',
#              ('extract', 'constrained'): 'formal',
#              ('constrained', 'formal'): 'concepts',
#              ('formal', 'concepts'): '.',
#              ('concepts', '.'): '_EOS_',
#              ('_UNK_', 'comments'): 'on',
#              ('comments', 'on'): '``',
#              ('on', '"'): 'approaching',
#              ('"', 'a'): 'primal',
#              ('new', 'combination'): 'of',
#              ('combination', 'of'): 'evidence',
#              ('of', 'evidence'): 'based',
#              ('evidence', 'based'): 'on',
#              ('based', 'on'): 'a',
#              ('on', 'compromise'): "''",
#              ('compromise', '"'): 'by',
#              ('"', 'by'): 'cong',
#              ('by', 'k'): '.',
#              ('k', '.'): 'yamada',
#              ('.', 'yamada'): '_EOS_',
#              ('yamada', ';'): 'comments',
#              (';', 'comments'): 'on',
#              ('on', '``'): 'a',
#              ('``', 'a'): 'new',
#              ('compromise', "''"): 'by',
#              ("''", 'by'): 'k',
#              ('_UNK_', 'learning'): 'states',
#              ('learning', 'low'): '-',
#              ('low', '-'): 'shot',
#              ('-', 'shot'): 'face',
#              ('shot', 'facial'): 'representations',
#              ('facial', 'representations'): 'via',
#              ('representations', 'via'): '2d',
#              ('via', '2d'): 'warping',
#              ('2d', 'warping'): 'module',
#              ('warping', ';'): 'in',
#              ('this', 'work'): 'is',
#              ('work', ','): 'we',
#              ('we', 'mainly'): 'study',
#              ('mainly', 'study'): 'the',
#              ('study', 'the'): 'connection',
#              ('the', 'influence'): 'of',
#              ('influence', 'of'): 'the',
#              ('the', '2d'): 'warping',
#              ('warping', 'module'): 'for',
#              ('module', 'for'): 'one',
#              ('for', 'one'): '-',
#              ('one', '-'): 'out',
#              ('shot', 'face'): 'recognition',
#              ('face', 'recognition'): '.',
#              ('recognition', '.'): '_EOS_',
#              ('_UNK_', 'automatic'): 'liver',
#              ('automatic', 'generation'): 'of',
#              ('generation', 'of'): 'benchmarks',
#              ('of', 'benchmarks'): 'for',
#              ('benchmarks', 'for'): 'plagiarism',
#              ('for', 'plagiarism'): 'detection',
#              ('plagiarism', 'detection'): 'tools',
#              ('detection', 'tools'): 'using',
#              ('tools', 'using'): 'grammatical',
#              ('using', 'grammatical'): 'evolution',
#              ('grammatical', 'evolution'): ';',
#              ('authors', 'due'): 'to',
#              ('a', 'major'): 'rewriting',
#              ('major', 'rewriting'): '.',
#              ('rewriting', '.'): '_EOS_',
#              ('_UNK_', 'resource'): 'allocation',
#              ('allocation', 'of'): 'mu',
#              ('of', 'mu'): '-',
#              ('mu', '-'): 'ofdm',
#              ('-', 'ofdm'): 'based',
#              ('systems', 'under'): 'partial',
#              ('under', 'partial'): 'channel',
#              ('partial', 'channel'): 'state',
#              ('channel', 'state'): 'information',
#              ('state', 'information'): ';',
#              ('information', ';'): 'this',
#              ('to', 'some'): 'errors',
#              ('some', 'errors'): '.',
#              ('_UNK_', 'advances'): 'in',
#              ('advances', 'in'): 'artificial',
#              ('in', 'artificial'): 'intelligence',
#              ('artificial', 'intelligence'): ';',
#              ('intelligence', 'require'): 'progress',
#              ('require', 'progress'): 'across',
#              ('progress', 'across'): 'all',
#              ('across', 'all'): 'of',
#              ('all', 'of'): 'computer',
#              ('of', 'computer'): 'science',
#              ('computer', 'science'): 'and',
#              ('science', ';'): 'advances',
#              (';', 'advances'): 'in',
#              ('science', '.'): '_EOS_',
#              ('_UNK_', 'exploration'): 'of',
#              ('exploration', 'of'): 'object',
#              ('of', 'object'): 'recognition',
#              ('object', 'recognition'): 'from',
#              ('recognition', 'from'): '3d',
#              ('from', '3d'): 'point',
#              ('3d', 'point'): 'cloud',
#              ('point', 'cloud'): 'data',
#              ('cloud', ';'): 'we',
#              ('present', 'our'): 'latest',
#              ('our', 'latest'): 'experiment',
#              ('latest', 'experiment'): 'results',
#              ('experiment', 'results'): 'of',
#              ('cloud', 'data'): 'collected',
#              ('data', 'collected'): 'through',
#              ('collected', 'through'): 'moving',
#              ('through', 'moving'): 'car',
#              ('moving', 'car'): '.',
#              ('car', '.'): '_EOS_',
#              ('_UNK_', 'quantified'): 'conditional',
#              ('quantified', 'conditional'): 'logic',
#              ('conditional', 'logics'): 'are',
#              ('logics', 'are'): 'fragments',
#              ('are', 'fragments'): 'of',
#              ('fragments', 'of'): 'hol',
#              ('of', 'hol'): ';',
#              ('hol', ';'): 'a',
#              ('a', 'semantic'): 'embedding',
#              ('semantic', 'embedding'): 'of',
#              ('embedding', 'of'): '(',
#              ('of', '('): 'constant',
#              ('(', 'constant'): 'domain',
#              ('constant', 'domain'): ')',
#              ('domain', ')'): 'quantified',
#              (')', 'quantified'): 'conditional',
#              ('conditional', 'logic'): 'in',
#              ('logic', 'in'): 'classical',
#              ('in', 'classical'): 'higher',
#              ('classical', 'higher'): '-',
#              ('higher', '-'): 'order',
#              ('-', 'order'): 'logic',
#              ('order', 'logic'): 'is',
#              ('logic', 'is'): 'presented',
#              ('is', 'presented'): 'as',
#              ('presented', '.'): '_EOS_',
#              ('_UNK_', 'in'): 'memoriam',
#              ('in', 'memoriam'): 'maurice',
#              ('memoriam', 'maurice'): 'gross',
#              ('maurice', 'gross'): '(',
#              ('gross', ';'): 'maurice',
#              (';', 'maurice'): 'gross',
#              ('gross', '('): '1934',
#              ('(', '1934'): '-',
#              ('1934', '-'): '2001',
#              ('-', '2001'): ')',
#              ('2001', ')'): 'was',
#              (')', 'was'): 'both',
#              ('was', 'both'): 'a',
#              ('both', 'a'): 'great',
#              ('a', 'great'): 'linguist',
#              ('great', 'linguist'): 'and',
#              ('linguist', 'and'): 'a',
#              ('and', 'a'): 'pioneer',
#              ('a', 'pioneer'): 'in',
#              ('pioneer', 'in'): 'natural',
#              ('in', 'natural'): 'language',
#              ('processing', '.'): 'this',
#              ('.', 'this'): 'article',
#              ('is', 'written'): 'in',
#              ('written', 'in'): 'homage',
#              ('in', 'homage'): 'to',
#              ('homage', 'to'): 'his',
#              ('to', 'his'): 'memory',
#              ('his', 'memory'): '_EOS_',
#              ('_UNK_', 'introduction'): 'to',
#              ('the', '26th'): 'international',
#              ('26th', 'international'): 'conference',
#              ('on', 'logic'): 'programming',
#              ('logic', 'programming'): 'classes',
#              ('programming', 'special'): 'issue',
#              ('issue', ';'): 'this',
#              ('is', 'the'): 'proceedings',
#              ('the', 'preface'): 'to',
#              ('preface', 'to'): 'the',
#              ('_UNK_', 'beyond'): 'description',
#              ('beyond', 'description'): '.',
#              ('description', '.'): 'comment',
#              ('.', 'comment'): 'on',
#              ('"', 'approaching'): 'human',
#              ('approaching', 'human'): 'language',
#              ('human', 'language'): 'in',
#              ('language', 'with'): 'complex',
#              ('with', 'complex'): 'networks',
#              ('networks', '"'): 'by',
#              ('by', 'cong'): '&',
#              ('cong', '&'): 'liu',
#              ('&', 'liu'): '_EOS_',
#              ('liu', ';'): 'comment',
#              (';', 'comment'): 'on',
#              ('_UNK_', 'norm'): '-',
#              ('norm', '-'): 'constrained',
#              ('-', 'based'): 'convergence',
#              ('based', 'capacity'): 'control',
#              ('capacity', 'control'): 'in',
#              ('control', 'in'): 'neural',
#              ('in', 'neural'): 'networks',
#              ('we', 'investigate'): 'the',
#              ('investigate', 'the'): 'grapheme',
#              ('the', 'capacity'): ',',
#              ('capacity', ','): 'convexity',
#              (',', 'convexity'): 'and',
#              ('convexity', 'and'): 'characterization',
#              ('and', 'characterization'): 'of',
#              ('characterization', 'of'): 'a',
#              ('a', 'general'): 'class',
#              ('general', 'family'): 'of',
#              ('family', 'of'): 'norm',
#              ('of', 'norm'): '-',
#              ('-', 'constrained'): 'feed',
#              ('constrained', 'feed'): '-',
#              ('feed', '-'): 'forward',
#              ('-', 'forward'): 'networks',
#              ('forward', 'networks'): '.',
#              ('networks', '.'): '_EOS_',
#              ('_UNK_', 'about'): 'compression',
#              ('about', 'compression'): 'of',
#              ('compression', 'of'): 'vocabulary',
#              ('of', 'vocabulary'): 'in',
#              ('vocabulary', 'in'): 'computer',
#              ('in', 'computer'): 'science',
#              ('computer', 'oriented'): 'languages',
#              ('oriented', 'languages'): '.',
#              ('languages', ';'): 'the',
#              ('author', 'uses'): 'the',
#              ('uses', 'the'): 'entropy',
#              ('the', 'entropy'): 'of',
#              ('entropy', 'of'): 'the',
#              ('the', 'ideal'): 'bose',
#              ('ideal', 'bose'): '-',
#              ('bose', '-'): 'einstein',
#              ('-', 'einstein'): 'gas',
#              ('einstein', 'gas'): 'to',
#              ('gas', 'to'): 'minimize',
#              ('to', 'minimize'): 'losses',
#              ('minimize', 'losses'): 'in',
#              ('losses', 'in'): 'computer',
#              ('computer', '-'): 'oriented',
#              ('-', 'oriented'): 'languages',
#              ('languages', '.'): '_EOS_',
#              ('_UNK_', 'unary'): 'coding',
#              ('unary', 'coding'): 'of',
#              ('coding', 'for'): 'neural',
#              ('for', 'neural'): 'network',
#              ('network', 'learning'): ';',
#              ('learning', ';'): 'this',
#              ('presents', 'some'): 'properties',
#              ('some', 'properties'): 'of',
#              ('properties', 'of'): 'the',
#              ('of', 'unary'): 'coding',
#              ('coding', 'of'): 'significance',
#              ('of', 'significance'): 'for',
#              ...})

# %%
# let's test it
dummy_lines = sorted(lines, key=len)[:100]
dummy_counts = count_ngrams(dummy_lines, n=3)
assert set(map(len, dummy_counts.keys())) == {2}, "please only count {n-1}-grams"
assert len(dummy_counts[('_UNK_', '_UNK_')]) == 78
assert dummy_counts['_UNK_', 'a']['note'] == 3
assert dummy_counts['p', '=']['np'] == 2
assert dummy_counts['author', '.']['_EOS_'] == 1

# %%
for q,k in dummy_counts.items():
  print(q)
  print(k)
  break
# Out:
# ('_UNK_', '_UNK_')
# Counter({'a': 13, 'the': 3, 'on': 3, 'using': 2, 'learning': 2, 'automatic': 2, 'why': 2, 'proceedings': 2, 'piecewise': 2, 'differential': 1, 'what': 1, 'p': 1, 'computational': 1, 'weak': 1, 'creating': 1, 'defeasible': 1, 'essence': 1, 'deep': 1, 'statistical': 1, 'complex': 1, 'serious': 1, 'preprocessing': 1, 'liquid': 1, 'mining': 1, 'towards': 1, 'icon': 1, 'recognition': 1, 'glottochronologic': 1, 'utility': 1, 'temporized': 1, 'backpropagation': 1, 'random': 1, 'network': 1, 'glottochronology': 1, 'time': 1, 'convolutional': 1, 'fitness': 1, 'flip': 1, 'autonomous': 1, 'activitynet': 1, 'decision': 1, 'text': 1, 'discrimination': 1, 'are': 1, 'extraction': 1, 'comments': 1, 'resource': 1, 'advances': 1, 'exploration': 1, 'quantified': 1, 'in': 1, 'introduction': 1, 'beyond': 1, 'norm': 1, 'about': 1, 'unary': 1, 'some': 1, 'convex': 1, 'neurocontrol': 1, 'philosophy': 1, 'parallels': 1, 'an': 1, 'calculate': 1, 'group': 1, 'entropy': 1, 'word': 1, 'guarded': 1, 'cornell': 1, 'semistability': 1, 'attack': 1, 'standardization': 1, 'defensive': 1, 'how': 1, 'technical': 1, 'sat': 1, 'approximated': 1, 'solving': 1, 'agent': 1})

# %% [markdown]
# Once we can count N-grams, we can build a probabilistic language model.
# The simplest way to compute probabilities is in proporiton to counts:
#
# $$ P(w_t | prefix) = { Count(prefix, w_t) \over \sum_{\hat w} Count(prefix, \hat w) } $$

# %%
class NGramLanguageModel:
    def __init__(self, lines, n):
        """
        Train a simple count-based language model:
        compute probabilities P(w_t | prefix) given ngram counts

        :param n: computes probability of next token given (n - 1) previous words
        :param lines: an iterable of strings with space-separated tokens
        """
        assert n >= 1
        self.n = n

        counts = count_ngrams(lines, self.n)

        # compute token proabilities given counts
        self.probs = defaultdict(Counter)
        # probs[(word1, word2)][word3] = P(word3 | word1, word2)

        # populate self.probs with actual probabilities
        for prefix, token_counts in counts.items():
            total_count = sum(token_counts.values())
            self.probs[prefix] = {token: count / total_count for token, count in token_counts.items()}

    def get_possible_next_tokens(self, prefix):
        """
        :param prefix: string with space-separated prefix tokens
        :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
        """
        prefix = prefix.split()
        prefix = prefix[max(0, len(prefix) - self.n + 1):]
        prefix = [ UNK ] * (self.n - 1 - len(prefix)) + prefix
        return self.probs[tuple(prefix)]

    def get_next_token_prob(self, prefix, next_token):
        """
        :param prefix: string with space-separated prefix tokens
        :param next_token: the next token to predict probability for
        :returns: P(next_token|prefix) a single number, 0 <= P <= 1
        """
        return self.get_possible_next_tokens(prefix).get(next_token, 0)

# %% [markdown]
# Let's test it!

# %%
dummy_lm.get_possible_next_tokens('a')
# Out:
# {'notation': 0.07692307692307693,
#  'note': 0.23076923076923078,
#  'comment': 0.07692307692307693,
#  'machine': 0.15384615384615385,
#  'theory': 0.07692307692307693,
#  'survey': 0.07692307692307693,
#  'history': 0.07692307692307693,
#  'new': 0.07692307692307693,
#  'remark': 0.07692307692307693,
#  'primer': 0.07692307692307693}

# %%
dummy_lm = NGramLanguageModel(dummy_lines, n=3)

p_initial = dummy_lm.get_possible_next_tokens('') # '' -> ['_UNK_', '_UNK_']
assert np.allclose(p_initial['learning'], 0.02)
assert np.allclose(p_initial['a'], 0.13)
assert np.allclose(p_initial.get('meow', 0), 0)
assert np.allclose(sum(p_initial.values()), 1)

p_a = dummy_lm.get_possible_next_tokens('a') # '' -> ['_UNK_', 'a']
assert np.allclose(p_a['machine'], 0.15384615)
assert np.allclose(p_a['note'], 0.23076923)
assert np.allclose(p_a.get('the', 0), 0)
assert np.allclose(sum(p_a.values()), 1)

assert np.allclose(dummy_lm.get_possible_next_tokens('a note')['on'], 1)
assert dummy_lm.get_possible_next_tokens('a machine') == \
    dummy_lm.get_possible_next_tokens("there have always been ghosts in a machine"), \
    "your 3-gram model should only depend on 2 previous words"

# %% [markdown]
# Now that you've got a working n-gram language model, let's see what sequences it can generate. But first, let's train it on the whole dataset.

# %%
lm = NGramLanguageModel(lines, n=3)

# %% [markdown]
# The process of generating sequences is... well, it's sequential. You maintain a list of tokens and iteratively add next token by sampling with probabilities.
#
# $ X = [] $
#
# __forever:__
# * $w_{next} \sim P(w_{next} | X)$
# * $X = concat(X, w_{next})$
#
#
# Instead of sampling with probabilities, one can also try always taking most likely token, sampling among top-K most likely tokens or sampling with temperature. In the latter case (temperature), one samples from
#
# $$w_{next} \sim {P(w_{next} | X) ^ {1 / \tau} \over \sum_{\hat w} P(\hat w | X) ^ {1 / \tau}}$$
#
# Where $\tau > 0$ is model temperature. If $\tau << 1$, more likely tokens will be sampled with even higher probability while less likely tokens will vanish.

# %%
prefix = 'artificial' # <- your ideas :)

# %%
item,key = list(zip(*lm.get_possible_next_tokens(prefix).items()))

# %%
key
# Out:
# (0.29411764705882354,
#  0.0196078431372549,
#  0.0392156862745098,
#  0.0196078431372549,
#  0.35294117647058826,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0392156862745098,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549,
#  0.0196078431372549)

# %%
def get_next_token(lm, prefix, temperature=1.0):
    """
    return next token after prefix;
    :param temperature: samples proportionally to lm probabilities ^ (1 / temperature)
        if temperature == 0, always takes most likely token. Break ties arbitrarily.
    """

    possible_next_tokens,probs = list(zip(*lm.get_possible_next_tokens(prefix).items()))
    probs = np.array(probs)

    if temperature == 0:
      return possible_next_tokens[np.argmax(probs)]

    probs = (probs)**(1/temperature) / ((probs)**(1/temperature)).sum()

    return np.random.choice(possible_next_tokens, p=probs)

# %%
from collections import Counter
test_freqs = Counter([get_next_token(lm, 'there have') for _ in range(10000)])
assert 250 < test_freqs['not'] < 450
assert 8500 < test_freqs['been'] < 9500
assert 1 < test_freqs['lately'] < 200

test_freqs = Counter([get_next_token(lm, 'deep', temperature=1.0) for _ in range(10000)])
assert 1500 < test_freqs['learning'] < 3000
test_freqs = Counter([get_next_token(lm, 'deep', temperature=0.5) for _ in range(10000)])
assert 8000 < test_freqs['learning'] < 9000
test_freqs = Counter([get_next_token(lm, 'deep', temperature=0.0) for _ in range(10000)])
assert test_freqs['learning'] == 10000

print("Looks nice!")
# Out:
# Looks nice!

# %% [markdown]
# Let's have fun with this model

# %%
prefix = 'artificial' # <- your ideas :)

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break

print(prefix)
# Out:
# artificial neural networks ( fcn ) and machine learning is thus of great interest in machine learning community due to how development can be efficiently trained in a multi - scale paragraph datasets are conducted for the conditional pseudo - random model for data mining and network text classifier of opencv api , and is freely available online , with high probability that a real enterprise security system based on a large number of training data in digital ecosystems : evolving service - based approach for knowledge base work in large amounts of computational resource constraints ; symmetry is an approach

# %%
prefix = 'bridging the' # <- more of your ideas

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix, temperature=0.5)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break

print(prefix)
# Out:
# bridging the gap between the two paradigms and prove that the technique to generate a set of labeled data . we show that the proposed algorithm is the first time , and ( 2 ) the number of clusters , graphs and its variants , and the other hand , the algorithm is proposed . the conventional methods are based on the following contributions . first , we propose a novel approach for the first time , while the latter can be used to train a classifier , and the other hand , the proposed method , we propose a new approach

# %% [markdown]
# __More in the homework:__ nucleus sampling, top-k sampling, beam search(not for the faint of heart).

# %% [markdown]
# ### Evaluating language models: perplexity (1point)
#
# Perplexity is a measure of how well your model approximates the true probability distribution behind the data. __Smaller perplexity = better model__.
#
# To compute perplexity on one sentence, use:
# $$
#     {\mathbb{P}}(w_1 \dots w_N) = P(w_1, \dots, w_N)^{-\frac1N} = \left( \prod_t P(w_t \mid w_{t - n}, \dots, w_{t - 1})\right)^{-\frac1N},
# $$
#
#
# On the corpora level, perplexity is a product of probabilities of all tokens in all sentences to the power of $1/N$, where $N$ is __total length (in tokens) of all sentences__ in corpora.
#
# This number can quickly get too small for float32/float64 precision, so we recommend you to first compute log-perplexity (from log-probabilities) and then take the exponent.

# %%
def perplexity(lm, lines, min_logprob=np.log(10 ** -50.)):
    """
    :param lines: a list of strings with space-separated tokens
    :param min_logprob: if log(P(w | ...)) is smaller than min_logprop, set it equal to min_logrob
    :returns: corpora-level perplexity - a single scalar number from the formula above

    Note: do not forget to compute P(w_first | empty) and P(eos | full_sequence)

    PLEASE USE lm.get_next_token_prob and NOT lm.get_possible_next_tokens
    """
    <YOUR CODE>

    return <...>

# %%
lm1 = NGramLanguageModel(dummy_lines, n=1)
lm3 = NGramLanguageModel(dummy_lines, n=3)
lm10 = NGramLanguageModel(dummy_lines, n=10)

ppx1 = perplexity(lm1, dummy_lines)
ppx3 = perplexity(lm3, dummy_lines)
ppx10 = perplexity(lm10, dummy_lines)
ppx_missing = perplexity(lm3, ['the jabberwock , with eyes of flame , '])  # thanks, L. Carrol

print("Perplexities: ppx1=%.3f ppx3=%.3f ppx10=%.3f" % (ppx1, ppx3, ppx10))

assert all(0 < ppx < 500 for ppx in (ppx1, ppx3, ppx10)), "perplexity should be non-negative and reasonably small"
assert ppx1 > ppx3 > ppx10, "higher N models should overfit and "
assert np.isfinite(ppx_missing) and ppx_missing > 10 ** 6, "missing words should have large but finite perplexity. " \
    " Make sure you use min_logprob right"
assert np.allclose([ppx1, ppx3, ppx10], (318.2132342216302, 1.5199996213739575, 1.1838145037901249))

# %% [markdown]
# Now let's measure the actual perplexity: we'll split the data into train and test and score model on test data only.

# %%
from sklearn.model_selection import train_test_split
train_lines, test_lines = train_test_split(lines, test_size=0.25, random_state=42)

for n in (1, 2, 3):
    lm = NGramLanguageModel(n=n, lines=train_lines)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))

# %%
# whoops, it just blew up :)

# %% [markdown]
# ### LM Smoothing
#
# The problem with our simple language model is that whenever it encounters an n-gram it has never seen before, it assigns it with the probabilitiy of 0. Every time this happens, perplexity explodes.
#
# To battle this issue, there's a technique called __smoothing__. The core idea is to modify counts in a way that prevents probabilities from getting too low. The simplest algorithm here is Additive smoothing (aka [Lapace smoothing](https://en.wikipedia.org/wiki/Additive_smoothing)):
#
# $$ P(w_t | prefix) = { Count(prefix, w_t) + \delta \over \sum_{\hat w} (Count(prefix, \hat w) + \delta) } $$
#
# If counts for a given prefix are low, additive smoothing will adjust probabilities to a more uniform distribution. Not that the summation in the denominator goes over _all words in the vocabulary_.
#
# Here's an example code we've implemented for you:

# %%
class LaplaceLanguageModel(NGramLanguageModel):
    """ this code is an example, no need to change anything """
    def __init__(self, lines, n, delta=1.0):
        self.n = n
        counts = count_ngrams(lines, self.n)
        self.vocab = set(token for token_counts in counts.values() for token in token_counts)
        self.probs = defaultdict(Counter)

        for prefix in counts:
            token_counts = counts[prefix]
            total_count = sum(token_counts.values()) + delta * len(self.vocab)
            self.probs[prefix] = {token: (token_counts[token] + delta) / total_count
                                          for token in token_counts}
    def get_possible_next_tokens(self, prefix):
        token_probs = super().get_possible_next_tokens(prefix)
        missing_prob_total = 1.0 - sum(token_probs.values())
        missing_prob = missing_prob_total / max(1, len(self.vocab) - len(token_probs))
        return {token: token_probs.get(token, missing_prob) for token in self.vocab}

    def get_next_token_prob(self, prefix, next_token):
        token_probs = super().get_possible_next_tokens(prefix)
        if next_token in token_probs:
            return token_probs[next_token]
        else:
            missing_prob_total = 1.0 - sum(token_probs.values())
            missing_prob_total = max(0, missing_prob_total) # prevent rounding errors
            return missing_prob_total / max(1, len(self.vocab) - len(token_probs))

# %% [markdown]
# **Disclaimer**: the implementation above assumes all words unknown within a given context to be equally likely, *as well as the words outside of vocabulary*. Therefore, its' perplexity will be lower than it should when encountering such words. Therefore, comparing it with a model with fewer unknown words will not be fair. When implementing your own smoothing, you may handle this by adding a virtual `UNK` token of non-zero probability. Technically, this will result in a model where probabilities do not add up to $1$, but it is close enough for a practice excercise.

# %%
#test that it's a valid probability model
for n in (1, 2, 3):
    dummy_lm = LaplaceLanguageModel(dummy_lines, n=n)
    assert np.allclose(sum([dummy_lm.get_next_token_prob('a', w_i) for w_i in dummy_lm.vocab]), 1), "I told you not to break anything! :)"

# %%
for n in (1, 2, 3):
    lm = LaplaceLanguageModel(train_lines, n=n, delta=0.1)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))

# %%
# optional: try to sample tokens from such a model

# %% [markdown]
# ### Kneser-Ney smoothing (2 points)
#
# Additive smoothing is simple, reasonably good but definitely not a State of The Art algorithm.
#
#
# Your final task in this notebook is to implement [Kneser-Ney](https://en.wikipedia.org/wiki/Kneser%E2%80%93Ney_smoothing) smoothing.
#
# It can be computed recurrently, for n>1:
#
# $$P_{kn}(w_t | prefix_{n-1}) = { \max(0, Count(prefix_{n-1}, w_t) - \delta) \over \sum_{\hat w} Count(prefix_{n-1}, \hat w)} + \lambda_{prefix_{n-1}} \cdot P_{kn}(w_t | prefix_{n-2})$$
#
# where
# - $prefix_{n-1}$ is a tuple of {n-1} previous tokens
# - $lambda_{prefix_{n-1}}$ is a normalization constant chosen so that probabilities add up to 1
# - Unigram $P_{kn}(w_t | prefix_{n-2})$ corresponds to Kneser Ney smoothing for {N-1}-gram language model.
# - Unigram $P_{kn}(w_t)$ is a special case: how likely it is to see x_t in an unfamiliar context
#
# See lecture slides or wiki for more detailed formulae.
#
# __Your task__ is to
# - implement `KneserNeyLanguageModel` class,
# - test it on 1-3 gram language models
# - find optimal (within reason) smoothing delta for 3-gram language model with Kneser-Ney smoothing

# %%
class KneserNeyLanguageModel(NGramLanguageModel):
    """ A template for Kneser-Ney language model. Default delta may be suboptimal. """
    def __init__(self, lines, n, delta=1.0):
        self.n = n
        <YOUR CODE>

    def get_possible_next_tokens(self, prefix):
        < YOUR CODE >

    def get_next_token_prob(self, prefix, next_token):
        <YOUR CODE>

# %%
#test that it's a valid probability model
for n in (1, 2, 3):
    dummy_lm = KneserNeyLanguageModel(dummy_lines, n=n)
    assert np.allclose(sum([dummy_lm.get_next_token_prob('a', w_i) for w_i in dummy_lm.vocab]), 1), "I told you not to break anything! :)"

# %%
for n in (1, 2, 3):
    lm = KneserNeyLanguageModel(train_lines, n=n, smoothing=<...>)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
